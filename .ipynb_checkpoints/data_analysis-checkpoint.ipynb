# %%
from numpy import mean, std
import pandas as pd
import yfinance as yf
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
plt.style.use('ggplot')

# %%
# define date range
start_date = '2005-01-22'
end_date  = datetime.today().strftime('%Y-%m-%d')

# %%
# retrieve markets

#data = yf.download(['GC=F', 'QLTA', '^TNX', 'SPY'], start_date, end_date)
data = yf.download(['MSFT', 'TSLA', 'AAPL', 'AMZN', 'SPY'], start_date, end_date)

print(data.head())
# Out:
# [*********************100%***********************]  5 of 5 completed
#            Adj Close                                        Close          \
#                 AAPL    AMZN       MSFT        SPY TSLA      AAPL    AMZN
# Date
# 2005-01-24  1.075448  2.0190  18.060871  81.935287  NaN  1.263571  2.0190
# 2005-01-25  1.095055  2.0470  18.307123  82.167305  NaN  1.286607  2.0470
# 2005-01-26  1.098095  2.0670  18.300089  82.413345  NaN  1.290179  2.0670
# 2005-01-27  1.104022  2.1155  18.370449  82.553932  NaN  1.297143  2.1155
# 2005-01-28  1.124388  2.1110  18.419695  82.553932  NaN  1.321071  2.1110
#
#                                         ...      Open                     \
#                  MSFT         SPY TSLA  ...      AAPL    AMZN       MSFT
# Date                                    ...
# 2005-01-24  25.670000  116.550003  NaN  ...  1.267500  2.0720  25.760000
# 2005-01-25  26.020000  116.879997  NaN  ...  1.274464  2.0320  25.760000
# 2005-01-26  26.010000  117.230003  NaN  ...  1.297500  2.0590  26.070000
# 2005-01-27  26.110001  117.430000  NaN  ...  1.288571  2.0635  25.950001
# 2005-01-28  26.180000  117.430000  NaN  ...  1.296786  2.1045  26.540001
#
#                                 Volume
#                    SPY TSLA       AAPL       AMZN       MSFT       SPY TSLA
# Date
# 2005-01-24  117.089996  NaN  841629600  193918000   69010900  58441900  NaN
# 2005-01-25  116.910004  NaN  969231200  180558000   67580700  68245000  NaN
# 2005-01-26  117.320000  NaN  739496800  154298000   64974500  57195100  NaN
# 2005-01-27  117.190002  NaN  496227200  160768000   93204100  55878800  NaN
# 2005-01-28  117.489998  NaN  801612000  123048000  110466500  60738900  NaN
#
# [5 rows x 30 columns]

# %%
# visualization functions

def rrg_plot(df, symbol, period = 20):
    """
    Method to visualize RRG plot for one market/symbol. The benchmark is SPY
    """
    df = df.copy()
    df =df.iloc[-period:]
    
    last = df.iloc[-1]    
    others = df.iloc[:-1]    

    plt.axvline(x = 0, color = 'b')
    plt.axhline(y = 0, color = 'b')

    plt.plot(df[f'{symbol}_ratio'], df[f'{symbol}_momentum'])
    plt.scatter(last[f'{symbol}_ratio'], last[f'{symbol}_momentum'], marker='o')
    plt.scatter(others[f'{symbol}_ratio'], others[f'{symbol}_momentum'], marker='x')

    plt.title(symbol)
    plt.xlabel("RS ratio")
    plt.ylabel("RS momentum")

    plt.show()
    
def visualize_rs(symbol:str):
    fig, ax = plt.subplots(2, 1, figsize=(10, 8))
    ax[0].plot(ratio_df[f'{symbol}_ratio'], label=ratio_df.columns)
    ax[0].set_title('RS ratio')
    #ax[0].legend()

    ax[1].plot(momentum_df[f'{symbol}_momentum'], label=momentum_df.columns)
    ax[1].set_title('RS momentum')
    #ax[1].legend()
    plt.show()

# %% [raw]
# # visualize assets and benchmark
#
# plt.figure(figsize = [10, 5])
# plt.plot(data[('Adj Close', 'GC=F')][-40:])
# plt.title('GC=F')
# plt.show()
#
# plt.figure(figsize = [10, 5])
# plt.plot(data[('Adj Close', 'QLTA')][-40:])
# plt.title('QLTA')
# plt.show()
# plt.figure(figsize = [10, 5])
#
# plt.plot(data[('Adj Close', '^TNX')][-40:])
# plt.title('^TNX')
# plt.show()
# plt.figure(figsize = [10, 5])
#
# plt.plot(data[('Adj Close', 'SPY')][-40:])
# plt.title('SPY')
# plt.show()

# %% [raw]
# # retrieve stocks
#
# data = yf.download(['SPY', 'AMZN', 'GOOG', 'AAPL', 'TSLA', 'MSFT'], start_date, end_date)

# %% [markdown]
# ### RRG on price complex

# %%
def rs_ratio(prices_df, benchmark, window=10):
    
    """
    Function that returns dataframe with relative strength ratio for each symbol (days)
    """
    
    # create new dataframe
    index = prices_df.index
    ratio_df = pd.DataFrame(index=index)
    ratio_df.index = pd.to_datetime(ratio_df.index)

    benchmark = benchmark.rolling(4).mean()

    for column in prices_df:
        prices_df[column] = prices_df[column].rolling(4).mean()

        rs = (prices_df[column] / benchmark) * 100
        rs = rs.rolling(window).mean()
        rs_ratio = [np.nan for i in range(int(window * 2))]
        
        for i in range(int(window * 2), len(rs)):
            rs_subset = rs[: i+1]                 
            ratio = (rs_subset[i] - rs_subset[int(-window * 2) : i-1].mean()) / rs_subset[int(-window * 2) : i-1].std() +1
            rs_ratio.append(ratio)    

        rs_ratio = pd.Series(rs_ratio, index = index)
        
        rs_ratio = rs_ratio.rolling(8).mean()

        ratio_df[f'{column}_ratio'] = rs_ratio
    
    ratio_df.dropna(axis=0, how='all', inplace=True)
    return ratio_df




def rs_momentum(ratio_df):
    index = ratio_df.index

    momentum_df = pd.DataFrame(index=index)

    for column in ratio_df:
        name = column.split('_')[0]
        rs_momentum = ratio_df[column] - ratio_df[column].shift(5)

        momentum_df[f'{name}_momentum'] = rs_momentum

    return momentum_df

# %%
# define date range
start_date = "2000-01-22"
end_date  = datetime.today().strftime('%Y-%m-%d')
date_range = pd.date_range(start=start_date, end=end_date, freq="B")


first_date = date_range[-165]
last_date = end_date

# subset within selected range
data1= data.copy()
data_loc = data1.loc[(data1.index > first_date) & (data1.index <= last_date)]




ratio_df = rs_ratio(data_loc["Adj Close"], data_loc[("Adj Close", 'SPY')])
plt.figure(figsize=[10, 5])
plt.plot(ratio_df['MSFT_ratio'])
plt.title('RS ratio')
plt.show()
momentum_df = rs_momentum(ratio_df)
plt.figure(figsize=[10, 5])
plt.plot(momentum_df['MSFT_momentum'])
plt.title('RS ratio')
plt.show()

# %% [raw]
# # define date range
# start_date = "2000-01-22"
# end_date  = datetime.today().strftime('%Y-%m-%d')
# date_range = pd.date_range(start=start_date, end=end_date, freq="B")
#
#
# first_date = date_range[-200]
# last_date = end_date
#
# # subset within selected range
# data1= data.copy()
# data_loc = data1.loc[(data1.index > first_date) & (data1.index <= last_date)]
#
#
#
#
# ratio_df = rs_ratio(data_loc["Adj Close"], data_loc[("Adj Close", 'SPY')])
# plt.figure(figsize=[10, 5])
# plt.plot(ratio_df['GC=F_ratio'])
# plt.title('RS ratio')
# plt.show()
# momentum_df = rs_momentum(ratio_df)
# plt.figure(figsize=[10, 5])
# plt.plot(momentum_df['GC=F_momentum'])
# plt.title('RS ratio')
# plt.show()

# %% [raw]
# ratio_df = rs_ratio(data["Adj Close"], data[("Adj Close", 'SPY')])
# plt.figure(figsize=[10, 5])
# plt.plot(ratio_df['GC=F_ratio'][-40:])
# plt.title('RS ratio')
# plt.show()
# momentum_df = rs_momentum(ratio_df)
# plt.figure(figsize=[10, 5])
# plt.plot(momentum_df['GC=F_momentum'][-40:])
# plt.title('RS momentum')
# plt.show()

# %%
def rrg_plot(df, symbol, period = 20):
    """
    Method to visualize RRG plot for one market/symbol. The benchmark is SPY
    """
    df = df.copy()
    df =df.iloc[-period:]
    
    last = df.iloc[-1]    
    others = df.iloc[:-1]    

    plt.axvline(x = 0, color = 'b')
    plt.axhline(y = 0, color = 'b')

    plt.plot(df[f'{symbol}_ratio'], df[f'{symbol}_momentum'])
    plt.scatter(last[f'{symbol}_ratio'], last[f'{symbol}_momentum'], marker='o')
    plt.scatter(others[f'{symbol}_ratio'], others[f'{symbol}_momentum'], marker='x')

    plt.title(symbol)
    plt.xlabel("RS ratio")
    plt.ylabel("RS momentum")

    plt.show()
    
df = pd.merge(ratio_df, momentum_df, left_on=ratio_df.index, right_on=momentum_df.index).set_index('key_0')

#rrg_plot(df, 'QLTA', 40)
#rrg_plot(df, 'GC=F', 40)
#rrg_plot(df, '^TNX', 40)

rrg_plot(df, 'MSFT', 100)
rrg_plot(df, 'AAPL', 100)
rrg_plot(df, 'TSLA', 100)

# %% [markdown]
# ### RRG on return simple

# %%
def rs_ratio(prices_df, benchmark, window=10):
    
    """
    Function that returns dataframe with relative strength ratio for each symbol (days)
    """
    
    # create new dataframe
    index = prices_df.index
    ratio_df = pd.DataFrame(index=index)
    ratio_df.index = pd.to_datetime(ratio_df.index)
    
    benchmark = benchmark.rolling(10).mean()
    benchmark = benchmark.pct_change(10)
    
    #plt.plot(benchmark[-200:])

    for column in prices_df:
        prices_df[column] = prices_df[column].rolling(10).mean()
        prices_df[f'{column}_return'] = prices_df[column].pct_change(10)
        prices_df[f'{column}_ratio'] = prices_df[f'{column}_return'] - benchmark
        
    return prices_df.rolling(8).mean()


def rs_momentum(ratio_df):
    index = ratio_df.index

    momentum_df = pd.DataFrame(index=index)

    for column in ratio_df:
        name = column.split('_')[0]
        rs_momentum = ratio_df[column] - ratio_df[column].shift(5)
        momentum_df[f'{name}_momentum'] = rs_momentum.rolling(8).mean()
        
    return momentum_df




ratio_df = rs_ratio(data['Adj Close'], data[('Adj Close', 'SPY')])
plt.figure(figsize=[10, 5])

#plt.plot(ratio_df['GC=F_ratio'][-40:])
plt.plot(ratio_df['MSFT_ratio'][-120:])

plt.title('RS ratio')
plt.show()

#----------------------------
momentum_df = rs_momentum(ratio_df)
plt.figure(figsize=[10, 5])

#plt.plot(momentum_df['GC=F_momentum'][-40:])
plt.plot(momentum_df['MSFT_momentum'][-120:])

plt.title('RS momentum')
plt.show()

# %%
    
df = pd.merge(ratio_df, momentum_df, left_on=ratio_df.index, right_on=momentum_df.index).set_index('key_0')

#rrg_plot(df, 'QLTA', 100)
#rrg_plot(df, 'GC=F', 100)
#rrg_plot(df, '^TNX', 100)

rrg_plot(df, 'TSLA', 100)
rrg_plot(df, 'AAPL', 100)
rrg_plot(df, 'MSFT', 100)

# %% [markdown]
# ### RRG on price, last window only

# %% [raw]
# # rs ratio window only
#
# def rs_ratio(prices_df, benchmark, window=14):
#     """
#     Function to return dataframe with relative strength ratio for each symbol
#     """
#
#     ratio_df = pd.DataFrame()
#
#     benchmark = benchmark.interpolate()
#     benchmark = benchmark.interpolate(limit_direction='backward')
#     prices_df = prices_df.interpolate()
#     prices_df = prices_df.interpolate(limit_direction='backward')
#
#     for column in prices_df:
#         rs = (prices_df[column][-window*4:] / benchmark[-window*4:]) * 100
#         rs_ratio = rs.rolling(window).mean()
#         rel_ratio = 100 + ((rs_ratio - rs_ratio.mean()) / rs_ratio.std())
#         ratio_df[f'{column}_ratio'] = rel_ratio
#
#     ratio_df.dropna(axis=0, how='all', inplace=True)
#
#     return ratio_df
#
# ratio_df = rs_ratio(data['Adj Close'], data[('Adj Close', 'SPY')])

# %% [raw]
# # momentum window only
#
# def rs_momentum(prices_df, benchmark, window=14):
#     """
#     Function to return dataframe with relative strength momentum for each symbol
#     """
#
#     momentum_df = pd.DataFrame()
#
#     benchmark = benchmark.interpolate()
#     benchmark = benchmark.interpolate(limit_direction='backward')
#     prices_df = prices_df.interpolate()
#     prices_df = prices_df.interpolate(limit_direction='backward')
#
#     for column in prices_df:
#         rs = (prices_df[column][-window*4:] / benchmark[-window*4:]) * 100
#         rs_ratio = rs.rolling(window).mean()
#         rs_momentum = rs_ratio - rs_ratio.shift(5)
#         rel_momentum = 100 + ((rs_momentum - rs_momentum.mean()) / rs_momentum.std())
#         momentum_df[f'{column}_momentum'] = rel_momentum
#
#     momentum_df.dropna(axis=0, how='all', inplace=True)
#
#     return momentum_df
#
# momentum_df = rs_momentum(data['Adj Close'], data[('Adj Close', 'SPY')])

# %% [raw]
# # visualize relative strength ratio and momentum
#
# visualize_rs('MSFT')
# visualize_rs('TSLA')
#
# #visualize_rs('^TNX')
# #visualize_rs('GC=F')

# %% [raw]
# # rrg plot
#
# df = pd.merge(ratio_df, momentum_df, left_on=ratio_df.index, right_on=momentum_df.index).set_index('key_0')
#
# rrg_plot(df, 'QLTA', 40)
# rrg_plot(df, 'GC=F', 40)
# rrg_plot(df, '^TNX', 40)

# %% [markdown]
# ### RRG on returns

# %%
# ratio window only

def rs_ratio(prices_df, benchmark, window=14):
    """
    Function to return dataframe with relative strength ratio for each symbol
    """
    
    ratio_df = pd.DataFrame()
    
    benchmark = benchmark.interpolate()
    benchmark = benchmark.interpolate(limit_direction='backward')
    prices_df = prices_df.interpolate()
    prices_df = prices_df.interpolate(limit_direction='backward')
    
    index = prices_df.index
    for column in prices_df:
        rs_serie= []
        
        for i in range(window*4, len(prices_df[column])):
            
            subset_asset = prices_df[column][:i+1]
            subset_asset = subset_asset[-window*4:]
            
            subset_benchmark = benchmark[:i+1]
            subset_benchmark = subset_benchmark[-window*4:]
            
            rs = subset_asset / subset_benchmark * 100 
            rs = (rs - rs.mean()) / rs.std()

            rs_serie.append(rs[-1])
            
        rs_serie = pd.Series(rs_serie, index =index[window*4:])
        rs_ratio = rs_serie.rolling(window).mean()
       # rs_ratio = (rs_ratio - rs_ratio.mean()) / rs_ratio.std()
        
        ratio_df[f'{column}_ratio'] = rs_ratio
        
    ratio_df.dropna(axis=0, how='all', inplace=True)
    
    return ratio_df

ratio_df = rs_ratio(data['Adj Close'], data[('Adj Close', 'SPY')])

# %%
def rs_momentum(ratio_df):
    index = ratio_df.index

    momentum_df = pd.DataFrame(index=index)

    for column in ratio_df:
        name = column.split('_')[0]
        rs_momentum =  ratio_df[column] - ratio_df[column].shift(5)
        momentum_df[f'{name}_momentum'] = rs_momentum.rolling(4).mean()
        
    return momentum_df

momentum_df = rs_momentum(ratio_df)

# %%
    
#visualize_rs('^TNX')
visualize_rs('TSLA')
visualize_rs('AMZN')
visualize_rs('AAPL')
visualize_rs('MSFT')

# %%
### rrg plot

df = pd.merge(ratio_df, momentum_df, left_on=ratio_df.index, right_on=momentum_df.index).set_index('key_0')

#rrg_plot(df, 'QLTA', 200)
#rrg_plot(df, 'GC=F', 200)
#rrg_plot(df, '^TNX', 200)

rrg_plot(df, 'TSLA', 100)
rrg_plot(df, 'MSFT', 100)
