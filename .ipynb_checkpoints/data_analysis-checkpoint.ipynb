# %%
from numpy import mean, std
import pandas as pd
import yfinance as yf
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# define date range
start_date = '2005-01-22'
end_date  = datetime.today().strftime('%Y-%m-%d')

# %%
diction = {'Gold': 'GC=F', 'US treas bonds':'QLTA', '10y': '^TNX','sp500': 'SPY'}

for i in diction:
    print(diction[i])
# Out:
# GC=F
# QLTA
# ^TNX
# SPY

# %%
# retrieve markets

data = yf.download(['GC=F', 'QLTA', '^TNX', 'SPY'], start_date, end_date)
print(data)
# Out:
# [*********************100%***********************]  4 of 4 completed
#               Adj Close                                      Close             \
#                    GC=F       QLTA         SPY   ^TNX         GC=F       QLTA
# Date
# 2005-01-24   426.899994        NaN   82.248016  4.122   426.899994        NaN
# 2005-01-25   422.000000        NaN   82.480904  4.189   422.000000        NaN
# 2005-01-26   426.899994        NaN   82.727898  4.192   426.899994        NaN
# 2005-01-27   426.299988        NaN   82.868996  4.207   426.299988        NaN
# 2005-01-28   425.799988        NaN   82.868996  4.138   425.799988        NaN
# ...                 ...        ...         ...    ...          ...        ...
# 2023-03-02  1833.500000  46.099998  397.809998  4.073  1833.500000  46.099998
# 2023-03-03  1847.699951  46.560001  404.190002  3.964  1847.699951  46.560001
# 2023-03-06  1847.900024  46.430000  404.470001  3.983  1847.900024  46.430000
# 2023-03-07  1813.900024  46.330002  398.269989  3.975  1813.900024  46.330002
# 2023-03-08  1812.699951  46.240002  398.920013  3.976  1812.699951  46.240002
#
#                                       High             ...         Low         \
#                    SPY   ^TNX         GC=F       QLTA  ...         SPY   ^TNX
# Date                                                   ...
# 2005-01-24  116.550003  4.122   426.899994        NaN  ...  116.370003  4.120
# 2005-01-25  116.879997  4.189   422.000000        NaN  ...  116.720001  4.119
# 2005-01-26  117.230003  4.192   426.899994        NaN  ...  117.040001  4.167
# 2005-01-27  117.430000  4.207   426.299988        NaN  ...  116.980003  4.204
# 2005-01-28  117.430000  4.138   427.500000        NaN  ...  116.610001  4.128
# ...                ...    ...          ...        ...  ...         ...    ...
# 2023-03-02  397.809998  4.073  1836.300049  46.139999  ...  392.329987  4.044
# 2023-03-03  404.190002  3.964  1855.400024  46.680000  ...  399.029999  3.962
# 2023-03-06  404.470001  3.983  1853.800049  46.680000  ...  404.010010  3.897
# 2023-03-07  398.269989  3.975  1840.900024  46.509998  ...  397.630005  3.921
# 2023-03-08  398.920013  3.976  1812.900024  46.520000  ...  396.589996  3.976
#
#                    Open                                 Volume            \
#                    GC=F       QLTA         SPY   ^TNX     GC=F      QLTA
# Date
# 2005-01-24   426.899994        NaN  117.089996  4.136     20.0       NaN
# 2005-01-25   422.000000        NaN  116.910004  4.128     20.0       NaN
# 2005-01-26   426.899994        NaN  117.320000  4.196     20.0       NaN
# 2005-01-27   426.299988        NaN  117.190002  4.224  66923.0       NaN
# 2005-01-28   426.100006        NaN  117.489998  4.194  41282.0       NaN
# ...                 ...        ...         ...    ...      ...       ...
# 2023-03-02  1830.000000  45.980000  392.679993  4.050    154.0  108700.0
# 2023-03-03  1837.300049  46.400002  399.709991  4.013     61.0  104100.0
# 2023-03-06  1853.300049  46.680000  405.049988  3.905      5.0   40300.0
# 2023-03-07  1840.900024  46.509998  404.420013  3.940    450.0   58300.0
# 2023-03-08  1811.599976  46.470001  398.390015  3.960    450.0   74400.0
#
#
#                     SPY ^TNX
# Date
# 2005-01-24   58441900.0  0.0
# 2005-01-25   68245000.0  0.0
# 2005-01-26   57195100.0  0.0
# 2005-01-27   55878800.0  0.0
# 2005-01-28   60738900.0  0.0
# ...                 ...  ...
# 2023-03-02   85127800.0  0.0
# 2023-03-03   90038300.0  0.0
# 2023-03-06   72795900.0  0.0
# 2023-03-07  108310600.0  0.0
# 2023-03-08   74537300.0  0.0
#
# [4566 rows x 24 columns]

# %%
plt.plot(data[('Adj Close', 'GC=F')])
plt.title('GC=F')
plt.show()

plt.plot(data[('Adj Close', 'QLTA')])
plt.title('QLTA')
plt.show()

plt.plot(data[('Adj Close', '^TNX')][-60:])
plt.title('^TNX')
plt.show()

plt.plot(data[('Adj Close', 'SPY')][-60:])
plt.title('SPY')
plt.show()

# %% [raw]
# # retrieve stocks
#
# data = yf.download(['SPY', 'AMZN', 'GOOG', 'AAPL', 'TSLA', 'MSFT'], start_date, end_date)

# %%
# simple rs ratio

def rs_ratio(prices_df, benchmark, window=14):
    
    """
    Function that returns dataframe with relative strength ratio for each symbol
    """


    ratio_df = pd.DataFrame()
    
    benchmark = benchmark.interpolate()
    benchmark = benchmark.interpolate(limit_direction='backward')
    prices_df = prices_df.interpolate()
    prices_df = prices_df.interpolate(limit_direction='backward')
    
    for column in prices_df:
        
        rs = (prices_df[column] / benchmark) * 100
        rs = rs.rolling(window).mean() 
            
        ratio_df[f'{column}_ratio'] = rs
    ratio_df.dropna(axis=0, how='all', inplace=True)
    
    return ratio_df


ratio_df = rs_ratio(data['Adj Close'], data[('Adj Close', 'SPY')])
#plt.plot(data[('Adj Close', '^TNX')])

#plt.figure(figsize=[10, 5])
#plt.plot(ratio_df['^TNX_ratio'])
#plt.title('RS ratio')
#plt.show()
plt.figure(figsize=[10, 5])
plt.plot(ratio_df['^TNX_ratio'][-40:])
plt.title('RS ratio')
plt.show()

# %%
# rs ratio (growth percentage)


def rs_ratio(prices_df, benchmark, window=14):
    
    """
    Function that returns dataframe with relative strength ratio for each symbol
    """
    index = prices_df.index

    ratio_df = pd.DataFrame(index=index)
    ratio_df.index = pd.to_datetime(ratio_df.index)
    
    benchmark = benchmark.interpolate()
    benchmark = benchmark.interpolate(limit_direction='backward')
    prices_df = prices_df.interpolate()
    prices_df = prices_df.interpolate(limit_direction='backward')
    
    benchmark_averaged=  benchmark.rolling(window = 10).mean()
    benchmark_growth = (benchmark - benchmark_averaged.shift(3)) / benchmark_averaged.shift(3)
    print(benchmark_growth)

    
    for column in prices_df:
        
        price_df_averaged=  prices_df[column].rolling(window = 10).mean()
        
        asset_growth = (prices_df[column] - price_df_averaged.shift(3)) / price_df_averaged.shift(3)
        
        print(asset_growth)
        relative_growth = asset_growth / benchmark_growth
        
        relative_growth =  prices_df[column].rolling(window = 4).mean()
        plt.figure(figsize=[10, 5])
        plt.plot(relative_growth[-200:])
        plt.title(f'RS ratio {column}')
        plt.show()
            
        ratio_df[f'{column}_ratio'] = relative_growth
        
    ratio_df.dropna(axis=0, how='all', inplace=True)
    
    return ratio_df


ratio_df = rs_ratio(data['Adj Close'], data[('Adj Close', 'SPY')])
#plt.plot(data[('Adj Close', '^TNX')])

#plt.figure(figsize=[10, 5])
#plt.plot(ratio_df['^TNX_ratio'])
#plt.title('RS ratio')
#plt.show()
plt.figure(figsize=[10, 5])
plt.plot(ratio_df['^TNX_ratio'][-40:])
plt.title('RS ratio')
plt.show()
# Out:
# Date
# 2005-01-24         NaN
# 2005-01-25         NaN
# 2005-01-26         NaN
# 2005-01-27         NaN
# 2005-01-28         NaN
#                 ...
# 2023-03-02   -0.017120
# 2023-03-03    0.002749
# 2023-03-06    0.007919
# 2023-03-07   -0.003515
# 2023-03-08   -0.000867
# Name: (Adj Close, SPY), Length: 4566, dtype: float64
# Date
# 2005-01-24         NaN
# 2005-01-25         NaN
# 2005-01-26         NaN
# 2005-01-27         NaN
# 2005-01-28         NaN
#                 ...
# 2023-03-02    0.000202
# 2023-03-03    0.009214
# 2023-03-06    0.010223
# 2023-03-07   -0.008326
# 2023-03-08   -0.009291
# Name: GC=F, Length: 4566, dtype: float64
# Date
# 2005-01-24         NaN
# 2005-01-25         NaN
# 2005-01-26         NaN
# 2005-01-27         NaN
# 2005-01-28         NaN
#                 ...
# 2023-03-02   -0.012281
# 2023-03-03   -0.000674
# 2023-03-06   -0.001381
# 2023-03-07   -0.001723
# 2023-03-08   -0.003441
# Name: QLTA, Length: 4566, dtype: float64
# Date
# 2005-01-24         NaN
# 2005-01-25         NaN
# 2005-01-26         NaN
# 2005-01-27         NaN
# 2005-01-28         NaN
#                 ...
# 2023-03-02   -0.017120
# 2023-03-03    0.002749
# 2023-03-06    0.007919
# 2023-03-07   -0.003515
# 2023-03-08   -0.000867
# Name: SPY, Length: 4566, dtype: float64
# Date
# 2005-01-24         NaN
# 2005-01-25         NaN
# 2005-01-26         NaN
# 2005-01-27         NaN
# 2005-01-28         NaN
#                 ...
# 2023-03-02    0.055564
# 2023-03-03    0.022045
# 2023-03-06    0.020811
# 2023-03-07    0.011914
# 2023-03-08    0.009060
# Name: ^TNX, Length: 4566, dtype: float64

# %%
from numpy import mean, std



def rs_ratio(prices_df, benchmark, window=10):
    benchmark = benchmark.rolling(4).mean()
    
    for series in prices_df:
        prices_df[series]=  prices_df[series].rolling(4).mean()
        rs = (prices_df[series].divide(benchmark)) * 100
        rs_ratio = rs.rolling(window).mean()
        rel_ratio = 100 + ((rs_ratio - rs_ratio.mean()) / rs_ratio.std() + 1)
        prices_df[series] = rel_ratio
    prices_df.dropna(axis=0, how='all', inplace=True)
    return prices_df

ratio_df = rs_ratio(data['Adj Close'], data[('Adj Close', 'SPY')])
#plt.plot(data[('Adj Close', '^TNX')])

#plt.figure(figsize=[10, 5])
#plt.plot(ratio_df['^TNX_ratio'])
#plt.title('RS ratio')
#plt.show()
plt.figure(figsize=[10, 5])
plt.plot(ratio_df['^TNX'][-40:])
plt.title('RS ratio')
plt.show()
# Out:
# C:\Users\pietr\AppData\Local\Temp\ipykernel_11532\2428972461.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prices_df[series]=  prices_df[series].rolling(4).mean()
# C:\Users\pietr\AppData\Local\Temp\ipykernel_11532\2428972461.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prices_df[series] = rel_ratio
# C:\Users\pietr\AppData\Local\Temp\ipykernel_11532\2428972461.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prices_df.dropna(axis=0, how='all', inplace=True)

# %%
plt.figure(figsize=[10, 5])
plt.plot(data[('Adj Close', 'GC=F')][-48:].rolling(4).mean())
plt.title('GC=F')
plt.show()

plt.figure(figsize=[10, 5])
plt.plot(data[ ('Adj Close', 'SPY')][-48:].rolling(4).mean())
plt.title('SPY')
plt.show()

# %%
# rs ratio (rate)


def rs_ratio(prices_df, benchmark, window=14):
    
    """
    Function that returns dataframe with relative strength ratio for each symbol
    """
    index = prices_df.index

    ratio_df = pd.DataFrame(index=index)
    ratio_df.index = pd.to_datetime(ratio_df.index)
    benchmark = benchmark.interpolate()
    benchmark = benchmark.interpolate(limit_direction='backward')
    prices_df = prices_df.interpolate()
    prices_df = prices_df.interpolate(limit_direction='backward')
    
    for column in prices_df:
        
        rs = (prices_df[column] / benchmark) * 100
        rs = rs.rolling(window).mean()
        print(rs)
        rs_ratio = [np.nan for i in range(window * 2)]
        
        for i in range(window * 2, len(rs)):
            rs_subset = rs[: i+1]                 
            ratio = (rs_subset[i] - rs_subset[-window * 2 : i-1].mean()) / rs_subset[-window * 2 : i-1].std()
            rs_ratio.append(ratio)    
            
        ratio_df[f'{column}_ratio'] = rs_ratio
        
    ratio_df.dropna(axis=0, how='all', inplace=True)
    
    return ratio_df


ratio_df = rs_ratio(data['Adj Close'], data[('Adj Close', 'SPY')])
#plt.plot(data[('Adj Close', '^TNX')])

#plt.figure(figsize=[10, 5])
#plt.plot(ratio_df['^TNX_ratio'])
#plt.title('RS ratio')
#plt.show()
plt.figure(figsize=[10, 5])
plt.plot(ratio_df['^TNX_ratio'][-40:])
plt.title('RS ratio')
plt.show()
# Out:
# Date
# 2005-01-24           NaN
# 2005-01-25           NaN
# 2005-01-26           NaN
# 2005-01-27           NaN
# 2005-01-28           NaN
#                  ...
# 2023-03-02    455.315609
# 2023-03-03    455.359367
# 2023-03-06    455.951002
# 2023-03-07    456.389772
# 2023-03-08    457.199557
# Length: 4566, dtype: float64
# Date
# 2005-01-24          NaN
# 2005-01-25          NaN
# 2005-01-26          NaN
# 2005-01-27          NaN
# 2005-01-28          NaN
#                 ...
# 2023-03-02    11.560682
# 2023-03-03    11.559831
# 2023-03-06    11.563254
# 2023-03-07    11.578482
# 2023-03-08    11.596481
# Length: 4566, dtype: float64
# Date
# 2005-01-24      NaN
# 2005-01-25      NaN
# 2005-01-26      NaN
# 2005-01-27      NaN
# 2005-01-28      NaN
#               ...
# 2023-03-02    100.0
# 2023-03-03    100.0
# 2023-03-06    100.0
# 2023-03-07    100.0
# 2023-03-08    100.0
# Length: 4566, dtype: float64
# C:\Users\pietr\AppData\Local\Temp\ipykernel_11532\1118738944.py:27: RuntimeWarning: invalid value encountered in double_scalars
#   ratio = (rs_subset[i] - rs_subset[-window * 2 : i-1].mean()) / rs_subset[-window * 2 : i-1].std()
# Date
# 2005-01-24         NaN
# 2005-01-25         NaN
# 2005-01-26         NaN
# 2005-01-27         NaN
# 2005-01-28         NaN
#                 ...
# 2023-03-02    0.962888
# 2023-03-03    0.967401
# 2023-03-06    0.973427
# 2023-03-07    0.979614
# 2023-03-08    0.985086
# Length: 4566, dtype: float64

# %%
# relative strength momentum simple

def rs_momentum(prices_df, benchmark, window=14):
    """
    Function to return dataframe with relative strength momentum for each symbol
    """
    
    momentum_df = pd.DataFrame()
    
    benchmark = benchmark.interpolate()
    benchmark = benchmark.interpolate(limit_direction='backward')
    prices_df = prices_df.interpolate()
    prices_df = prices_df.interpolate(limit_direction='backward')
    
    for column in prices_df:
        
        rs = (prices_df[column][-window*4:] / benchmark[-window*4:]) * 100
        
        rs_ratio = rs.rolling(window).mean()
        
        rs_momentum = rs_ratio - rs_ratio.shift(5)
        
        #rel_momentum = 100 + ((rs_momentum - rs_momentum.mean()) / rs_momentum.std() + 1)
        #rel_momentum = 100 + ((rs_momentum - rs_momentum.mean()) / rs_momentum.std())
        
        momentum_df[f'{column}_momentum'] = rs_momentum
        
    momentum_df.dropna(axis=0, how='all', inplace=True)
    
    return momentum_df

momentum_df = rs_momentum(data['Adj Close'], data[('Adj Close', 'SPY')])
plt.figure(figsize=[10, 5])
plt.plot(momentum_df['^TNX_momentum'][-40:])
plt.title('RS momentum')
plt.show()

# %%
# trial dashboard






def rs_momentum(prices_df, benchmark, window=14):
    """
    Function that returns dataframe with relative strength momentum for each symbol
    """
    # create new dataframe
    index = prices_df.index

    momentum_df = pd.DataFrame(index=index)
    momentum_df.index = pd.to_datetime(momentum_df.index)
    
    benchmark = benchmark.interpolate()
    benchmark = benchmark.interpolate(limit_direction='backward')
    prices_df = prices_df.interpolate()
    prices_df = prices_df.interpolate(limit_direction='backward')
    
    for column in prices_df:
        
        rs = (prices_df[column] / benchmark) * 100
        rs = rs.rolling(window).mean()
        rs_ratio = [np.nan for i in range(window * 2)]
        
        for i in range(window * 2, len(rs)):
            rs_subset = rs[: i+1]                 
            ratio = (rs_subset[i] - rs_subset[-window * 2 : i-1].mean()) / rs_subset[-window * 2 : i-1].std()
            rs_ratio.append(ratio) 
            
        rs_ratio = pd.Series(rs_ratio, index = index)
        rs_momentum = pd.Series(rs_ratio) - pd.Series(rs_ratio).shift(5)
   
        momentum_df[f'{column}_momentum'] = rs_momentum
        
    momentum_df.dropna(axis=0, how='all', inplace=True)
    
    return momentum_df

momentum_df = rs_momentum(data['Adj Close'], data[('Adj Close', 'SPY')])
plt.figure(figsize=[10, 5])
plt.plot(momentum_df['^TNX_momentum'][-40:])
plt.title('RS momentum')
plt.show()
# Out:
# C:\Users\pietr\AppData\Local\Temp\ipykernel_11532\3110044187.py:31: RuntimeWarning: invalid value encountered in double_scalars
#   ratio = (rs_subset[i] - rs_subset[-window * 2 : i-1].mean()) / rs_subset[-window * 2 : i-1].std()

# %%
def rrg_plot(df, symbol, period = 20):
    """
    Method to visualize RRG plot for one market/symbol. The benchmark is SPY
    """
    df = df.copy()
    df =df.iloc[-period:]
    
    last = df.iloc[-1]    
    others = df.iloc[:-1]    

    plt.axvline(x = 0, color = 'b')
    plt.axhline(y = 0, color = 'b')

    plt.plot(df[f'{symbol}_ratio'], df[f'{symbol}_momentum'])
    plt.scatter(last[f'{symbol}_ratio'], last[f'{symbol}_momentum'], marker='o')
    plt.scatter(others[f'{symbol}_ratio'], others[f'{symbol}_momentum'], marker='x')

    plt.title(symbol)
    plt.xlabel("RS ratio")
    plt.ylabel("RS momentum")

    plt.show()
    
df = pd.merge(ratio_df, momentum_df, left_on=ratio_df.index, right_on=momentum_df.index).set_index('key_0')

rrg_plot(df, 'QLTA', 40)
rrg_plot(df, 'GC=F', 40)
rrg_plot(df, '^TNX', 40)

# %% [raw]
# def rs_momentum(prices_df, benchmark, window=14):
#
#     """
#     Function that returns dataframe with relative strength ratio for each symbol
#     """
#     index = prices_df.index
#
#     ratio_df = pd.DataFrame(index=index)
#     ratio_df.index = pd.to_datetime(ratio_df.index, utc = True)
#     benchmark = benchmark.interpolate()
#     benchmark = benchmark.interpolate(limit_direction='backward')
#     prices_df = prices_df.interpolate()
#     prices_df = prices_df.interpolate(limit_direction='backward')
#
#     for column in prices_df:
#         #rs = (prices_df[column][-window*4:] / benchmark[-window*4:]) * 100
#
#         rs = (prices_df[column] / benchmark) * 100
#
#         rs = rs.rolling(window).mean()
#         #rel_ratio = 100 + ((rs_ratio - rs_ratio.mean()) / rs_ratio.std() + 1)
#
#
#
#         rs_ratio = [np.nan for i in range(window * 2)]
#
#
#         for i in range(window * 2, len(rs)):
#
#             rs_subset = rs[: i+1]
#
#             rs_momentum = rs_subset[i] - rs_ratio[i-5]##############
#
#
#             ratio = (rs_subset[i] - rs_subset[-window * 2 : i-1].mean()) / rs_subset[-window * 2 : i-1].std()
#
#
#             rs_ratio.append(ratio)
#
#
#         ratio_df[f'{column}_ratio'] = rs_ratio
#
#
#     #ratio_df.index = pd.to_datetime(ratio_df.index, utc = True)
#
#     ratio_df.dropna(axis=0, how='all', inplace=True)
#
#     return ratio_df
#
#
#
# ratio_df = rs_ratio(data['Adj Close'], data[('Adj Close', 'SPY')])
# #plt.plot(data[('Adj Close', '^TNX')])
# plt.plot(ratio_df['^TNX_ratio'])

# %%
# rs ratio window only
def rs_ratio(prices_df, benchmark, window=14):
    """
    Function to return dataframe with relative strength ratio for each symbol
    """
    
    ratio_df = pd.DataFrame()
    
    benchmark = benchmark.interpolate()
    benchmark = benchmark.interpolate(limit_direction='backward')
    prices_df = prices_df.interpolate()
    prices_df = prices_df.interpolate(limit_direction='backward')
    
    for column in prices_df:
        rs = (prices_df[column][-window*4:] / benchmark[-window*4:]) * 100
        rs_ratio = rs.rolling(window).mean()
        #rel_ratio = 100 + ((rs_ratio - rs_ratio.mean()) / rs_ratio.std() + 1)
        
        rel_ratio = 100 + ((rs_ratio - rs_ratio.mean()) / rs_ratio.std())

        ratio_df[f'{column}_ratio'] = rel_ratio
        
    ratio_df.dropna(axis=0, how='all', inplace=True)
    
    return ratio_df

ratio_df = rs_ratio(data['Adj Close'], data[('Adj Close', 'SPY')])
plt.figure(figsize=[10, 5])

plt.plot(ratio_df['^TNX_ratio'])

# %%
# momentum window only

def rs_momentum(prices_df, benchmark, window=14):
    """
    Function to return dataframe with relative strength momentum for each symbol
    """
    
    momentum_df = pd.DataFrame()
    
    benchmark = benchmark.interpolate()
    benchmark = benchmark.interpolate(limit_direction='backward')
    prices_df = prices_df.interpolate()
    prices_df = prices_df.interpolate(limit_direction='backward')
    
    for column in prices_df:
        
        rs = (prices_df[column][-window*4:] / benchmark[-window*4:]) * 100
        
        rs_ratio = rs.rolling(window).mean()
        
        rs_momentum = rs_ratio - rs_ratio.shift(5)
        
  
        #rel_momentum = 100 + ((rs_momentum - rs_momentum.mean()) / rs_momentum.std() + 1)
        rel_momentum = 100 + ((rs_momentum - rs_momentum.mean()) / rs_momentum.std())
        
        momentum_df[f'{column}_momentum'] = rel_momentum
        
    momentum_df.dropna(axis=0, how='all', inplace=True)
    
    return momentum_df

momentum_df = rs_momentum(data['Adj Close'], data[('Adj Close', 'SPY')])
plt.figure(figsize=[10, 5])

plt.plot(momentum_df['^TNX_momentum'])

# %% [raw]
# # chatgpt
#
# def calculate_RSR(ticker, benchmark='^GSPC', period='1mo'):
#     """
#     Calculate the relative strength ratio (RSR) of a stock compared to a benchmark index over a given time period.
#
#     Args:
#     - ticker (str): The ticker symbol of the stock to analyze.
#     - benchmark (str, optional): The ticker symbol of the benchmark index to compare against. Default is '^GSPC' (S&P 500).
#     - period (str, optional): The time period to analyze. Valid options are '1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', and 'max'. Default is '1mo' (1 month).
#
#     Returns:
#     - The RSR of the stock compared to the benchmark index over the given time period.
#     """
#     # Get historical prices for the stock and the benchmark index
#     stock_data = yf.download(ticker, period=period)['Adj Close']
#     benchmark_data = yf.download(benchmark, period=period)['Adj Close']
#
#     # Calculate the average daily returns for both the stock and the benchmark index
#     stock_returns = stock_data.pct_change().mean()
#     benchmark_returns = benchmark_data.pct_change().mean()
#
#     # Calculate the RSR
#     RSR = stock_returns / benchmark_returns
#
#     return RSR
#
# RSR = calculate_RSR('TSLA', benchmark='^DJI', period='1y')
# print(RSR)

# %%
def visualize_rs(symbol:str):
    fig, ax = plt.subplots(2, 1, figsize=(10, 8))
    ax[0].plot(ratio_df[f'{symbol}_ratio'], label=ratio_df.columns)
    ax[0].set_title('RS ratio')
    #ax[0].legend()

    ax[1].plot(momentum_df[f'{symbol}_momentum'], label=momentum_df.columns)
    ax[1].set_title('RS momentum')
    #ax[1].legend()
    plt.show()
    
visualize_rs('^TNX')

# %%
# merge rs ratio and momentum data
df = pd.merge(ratio_df, momentum_df, left_on=ratio_df.index, right_on=momentum_df.index).set_index('key_0')

print(df[-5:])
# Out:
#             GC=F_ratio  QLTA_ratio  SPY_ratio  ^TNX_ratio  GC=F_momentum  \
# key_0
# 2023-03-02   98.760777   98.853833        NaN  101.154099     100.854820
# 2023-03-03   98.764597   98.850464        NaN  101.263673     100.803878
# 2023-03-06   98.816235   98.864006        NaN  101.410030     100.891779
# 2023-03-07   98.854531   98.924234        NaN  101.560279     100.832419
# 2023-03-08   98.925210   98.995427        NaN  101.693147     100.870782
#
#             QLTA_momentum  SPY_momentum  ^TNX_momentum
# key_0
# 2023-03-02     101.406119           NaN     101.297890
# 2023-03-03     101.335119           NaN     101.125804
# 2023-03-06     101.342225           NaN     101.092053
# 2023-03-07     101.308526           NaN     101.054450
# 2023-03-08     101.447384           NaN     100.951837

# %%
def rrg_plot(df, symbol, period = 20):
    """
    Method to visualize RRG plot for one market/symbol. The benchmark is SPY
    """
    df = df.copy()
    df =df.iloc[-period:]
    
    last = df.iloc[-1]    
    others = df.iloc[:-1]    

    plt.axvline(x = 100, color = 'b')
    plt.axhline(y = 100, color = 'b')

    plt.plot(df[f'{symbol}_ratio'], df[f'{symbol}_momentum'])
    plt.scatter(last[f'{symbol}_ratio'], last[f'{symbol}_momentum'], marker='o')
    plt.scatter(others[f'{symbol}_ratio'], others[f'{symbol}_momentum'], marker='x')

    plt.title(symbol)
    plt.xlabel("RS ratio")
    plt.ylabel("RS momentum")

    plt.show()
    

rrg_plot(df, 'QLTA', 40)
rrg_plot(df, 'GC=F', 40)
rrg_plot(df, '^TNX', 40)

# %%
# rs momentum for dashboard

def rs_momentum(prices_df, benchmark, window=14):
    """
    Function that returns dataframe with relative strength momentum for each symbol
    """
    # create new dataframe
    index = prices_df.index

    momentum_df = pd.DataFrame(index=index)
    momentum_df.index = pd.to_datetime(momentum_df.index)
    
    benchmark = benchmark.interpolate()
    benchmark = benchmark.interpolate(limit_direction='backward')
    prices_df = prices_df.interpolate()
    prices_df = prices_df.interpolate(limit_direction='backward')
    
    benchmark = benchmark.rolling(4).mean()

    for column in prices_df:
        prices_df[column] = prices_df[column].rolling(4).mean()

        rs = (prices_df[column] / benchmark) * 100
        #rs = rs.rolling(window).mean()
        rs_ratio = [np.nan for i in range(window * 2)]
        
        for i in range(window * 2, len(rs)):
            rs_subset = rs[: i+1]                 
            ratio = (rs_subset[i] - rs_subset[-window * 2 : i-1].mean()) / rs_subset[-window * 2 : i-1].std()
            rs_ratio.append(ratio) 
            
        rs_ratio = pd.Series(rs_ratio, index= index)
        rs_ratio = rs_ratio.rolling(4).mean()

        rs_momentum = pd.Series(rs_ratio) - pd.Series(rs_ratio).shift(1)
   
        momentum_df[f'{column}_momentum'] = rs_momentum
        
    momentum_df.dropna(axis=0, how='all', inplace=True)
    
    return momentum_df
