# %%
from numpy import mean, std
import pandas as pd
import yfinance as yf
import numpy as np

import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# define date range
start_date = '2005-01-22'
end_date = '2023-02-22'

# %%
diction = {'Gold': 'GC=F', 'US treas bonds':'QLTA', '10y': '^TNX','sp500': 'SPY'}

for i in diction:
    print(diction[i])
# Out:
# GC=F
# QLTA
# ^TNX
# SPY

# %%
# retrieve markets


data = yf.download(['GC=F', 'QLTA', '^TNX', 'SPY'], start_date, end_date)
print(data)
# Out:
# [*********************100%***********************]  4 of 4 completed
#               Adj Close                                      Close             \
#                    GC=F       QLTA         SPY   ^TNX         GC=F       QLTA
# Date
# 2005-01-24   426.899994        NaN   82.248001  4.122   426.899994        NaN
# 2005-01-25   422.000000        NaN   82.480896  4.189   422.000000        NaN
# 2005-01-26   426.899994        NaN   82.727882  4.192   426.899994        NaN
# 2005-01-27   426.299988        NaN   82.869011  4.207   426.299988        NaN
# 2005-01-28   425.799988        NaN   82.869011  4.138   425.799988        NaN
# ...                 ...        ...         ...    ...          ...        ...
# 2023-02-14  1854.000000  47.121967  412.640015  3.761  1854.000000  47.250000
# 2023-02-15  1834.199951  46.942455  413.980011  3.809  1834.199951  47.070000
# 2023-02-16  1842.000000  46.663216  408.279999  3.843  1842.000000  46.790001
# 2023-02-17  1840.400024  46.792858  407.260010  3.828  1840.400024  46.919998
# 2023-02-21  1833.000000  46.294216  399.089996  3.955  1833.000000  46.419998
#
#                                       High             ...         Low         \
#                    SPY   ^TNX         GC=F       QLTA  ...         SPY   ^TNX
# Date                                                   ...
# 2005-01-24  116.550003  4.122   426.899994        NaN  ...  116.370003  4.120
# 2005-01-25  116.879997  4.189   422.000000        NaN  ...  116.720001  4.119
# 2005-01-26  117.230003  4.192   426.899994        NaN  ...  117.040001  4.167
# 2005-01-27  117.430000  4.207   426.299988        NaN  ...  116.980003  4.204
# 2005-01-28  117.430000  4.138   427.500000        NaN  ...  116.610001  4.128
# ...                ...    ...          ...        ...  ...         ...    ...
# 2023-02-14  412.640015  3.761  1862.000000  47.369999  ...  408.510010  3.622
# 2023-02-15  413.980011  3.809  1842.000000  47.139999  ...  409.470001  3.749
# 2023-02-16  408.279999  3.843  1843.699951  47.060001  ...  408.140015  3.793
# 2023-02-17  407.260010  3.828  1842.199951  46.919998  ...  404.049988  3.824
# 2023-02-21  399.089996  3.955  1843.000000  46.630001  ...  398.820007  3.881
#
#                    Open                                 Volume            \
#                    GC=F       QLTA         SPY   ^TNX     GC=F      QLTA
# Date
# 2005-01-24   426.899994        NaN  117.089996  4.136     20.0       NaN
# 2005-01-25   422.000000        NaN  116.910004  4.128     20.0       NaN
# 2005-01-26   426.899994        NaN  117.320000  4.196     20.0       NaN
# 2005-01-27   426.299988        NaN  117.190002  4.224  66923.0       NaN
# 2005-01-28   426.100006        NaN  117.489998  4.194  41282.0       NaN
# ...                 ...        ...         ...    ...      ...       ...
# 2023-02-14  1854.099976  47.369999  411.239990  3.688    656.0   51800.0
# 2023-02-15  1842.000000  47.090000  410.350006  3.749    368.0   61400.0
# 2023-02-16  1838.599976  46.849998  408.790009  3.803    222.0  146700.0
# 2023-02-17  1827.400024  46.610001  406.059998  3.886     35.0   55100.0
# 2023-02-21  1842.599976  46.610001  403.059998  3.894    862.0   66800.0
#
#
#                    SPY ^TNX
# Date
# 2005-01-24  58441900.0  0.0
# 2005-01-25  68245000.0  0.0
# 2005-01-26  57195100.0  0.0
# 2005-01-27  55878800.0  0.0
# 2005-01-28  60738900.0  0.0
# ...                ...  ...
# 2023-02-14  88389300.0  0.0
# 2023-02-15  61555700.0  0.0
# 2023-02-16  76431500.0  0.0
# 2023-02-17  89257800.0  0.0
# 2023-02-21  82655900.0  0.0
#
# [4555 rows x 24 columns]

# %%
plt.plot(data[('Adj Close', 'GC=F')])
plt.title('GC=F')
plt.show()

plt.plot(data[('Adj Close', 'QLTA')])
plt.title('QLTA')
plt.show()

plt.plot(data[('Adj Close', '^TNX')][-60:])
plt.title('^TNX')
plt.show()

plt.plot(data[('Adj Close', 'SPY')][-60:])
plt.title('SPY')
plt.show()

# %% [raw]
# # retrieve stocks
#
#
# data = yf.download(['SPY', 'AMZN', 'GOOG', 'AAPL', 'TSLA', 'MSFT'], start_date, end_date)

# %%
print(data.columns)
print(data['Adj Close'].head())
# Out:
# MultiIndex([('Adj Close', 'GC=F'),
#             ('Adj Close', 'QLTA'),
#             ('Adj Close',  'SPY'),
#             ('Adj Close', '^TNX'),
#             (    'Close', 'GC=F'),
#             (    'Close', 'QLTA'),
#             (    'Close',  'SPY'),
#             (    'Close', '^TNX'),
#             (     'High', 'GC=F'),
#             (     'High', 'QLTA'),
#             (     'High',  'SPY'),
#             (     'High', '^TNX'),
#             (      'Low', 'GC=F'),
#             (      'Low', 'QLTA'),
#             (      'Low',  'SPY'),
#             (      'Low', '^TNX'),
#             (     'Open', 'GC=F'),
#             (     'Open', 'QLTA'),
#             (     'Open',  'SPY'),
#             (     'Open', '^TNX'),
#             (   'Volume', 'GC=F'),
#             (   'Volume', 'QLTA'),
#             (   'Volume',  'SPY'),
#             (   'Volume', '^TNX')],
#            )
#                   GC=F  QLTA        SPY   ^TNX
# Date
# 2005-01-24  426.899994   NaN  82.248001  4.122
# 2005-01-25  422.000000   NaN  82.480896  4.189
# 2005-01-26  426.899994   NaN  82.727882  4.192
# 2005-01-27  426.299988   NaN  82.869011  4.207
# 2005-01-28  425.799988   NaN  82.869011  4.138

# %%
def rs_ratio(prices_df, benchmark, window=14):
    """
    Function to return dataframe with relative strength ratio for each symbol
    """
    
    ratio_df = pd.DataFrame()
    
    benchmark = benchmark.interpolate()
    benchmark = benchmark.interpolate(limit_direction='backward')
    prices_df = prices_df.interpolate()
    prices_df = prices_df.interpolate(limit_direction='backward')
    
    for column in prices_df:
        rs = (prices_df[column][-window*4:] / benchmark[-window*4:]) * 100
        rs_ratio = rs.rolling(window).mean()
        #rel_ratio = 100 + ((rs_ratio - rs_ratio.mean()) / rs_ratio.std() + 1)
        
        rel_ratio = 100 + ((rs_ratio - rs_ratio.mean()) / rs_ratio.std())

        ratio_df[f'{column}_ratio'] = rel_ratio
        
    ratio_df.dropna(axis=0, how='all', inplace=True)
    
    return ratio_df

ratio_df = rs_ratio(data['Adj Close'], data[('Adj Close', 'SPY')])
print(ratio_df)
# Out:
#             GC=F_ratio  QLTA_ratio  SPY_ratio  ^TNX_ratio
# Date
# 2022-12-20   98.225681  100.186585        NaN   99.666259
# 2022-12-21   98.429229  100.357559        NaN   99.823588
# 2022-12-22   98.632655  100.564234        NaN  100.008278
# 2022-12-23   98.825773  100.685105        NaN  100.149052
# 2022-12-27   99.017552  100.707986        NaN  100.367295
# 2022-12-28   99.203444  100.729517        NaN  100.670624
# 2022-12-29   99.367997  100.738878        NaN  100.887219
# 2022-12-30   99.497269  100.734056        NaN  101.081363
# 2023-01-03   99.769139  100.838800        NaN  101.244594
# 2023-01-04   99.999800  100.938016        NaN  101.416865
# 2023-01-05  100.226723  101.046162        NaN  101.604051
# 2023-01-06  100.400013  101.014385        NaN  101.660768
# 2023-01-09  100.523612  100.959624        NaN  101.657517
# 2023-01-10  100.592177  100.857016        NaN  101.628840
# 2023-01-11  100.566887  100.771808        NaN  101.497968
# 2023-01-12  100.624353  100.754260        NaN  101.338019
# 2023-01-13  100.718500  100.647127        NaN  101.182467
# 2023-01-16  100.807128  100.577881        NaN  101.004177
# 2023-01-17  100.835667  100.534111        NaN  100.772004
# 2023-01-18  100.886274  100.554565        NaN  100.452277
# 2023-01-19  101.043173  100.655514        NaN  100.214972
# 2023-01-20  101.127578  100.665399        NaN   99.962317
# 2023-01-23  101.111367  100.568751        NaN   99.743717
# 2023-01-24  101.114744  100.504195        NaN   99.556119
# 2023-01-25  101.124483  100.397464        NaN   99.338161
# 2023-01-26  101.095141  100.282203        NaN   99.231530
# 2023-01-27  101.037004  100.134247        NaN   99.157027
# 2023-01-30  101.043516  100.071076        NaN   99.080536
# 2023-01-31  101.049203  100.004776        NaN   99.023360
# 2023-02-01  100.984845   99.900194        NaN   98.944441
# 2023-02-02  100.815679   99.767910        NaN   98.819777
# 2023-02-03  100.592168   99.639715        NaN   98.766471
# 2023-02-06  100.403477   99.510236        NaN   98.762716
# 2023-02-07  100.124561   99.210605        NaN   98.805638
# 2023-02-08   99.831955   98.934631        NaN   98.834796
# 2023-02-09   99.611383   98.766953        NaN   98.881189
# 2023-02-10   99.419718   98.633855        NaN   98.952132
# 2023-02-13   99.148603   98.436779        NaN   99.015285
# 2023-02-14   98.870235   98.238038        NaN   99.103190
# 2023-02-15   98.607699   98.058789        NaN   99.210643
# 2023-02-16   98.418031   97.929893        NaN   99.350071
# 2023-02-17   98.197997   97.783351        NaN   99.450761
# 2023-02-21   98.077567   97.707753        NaN   99.681923

# %%
def rs_momentum(prices_df, benchmark, window=14):
    """
    Function to return dataframe with relative strength momentum for each symbol
    """
    
    momentum_df = pd.DataFrame()
    
    benchmark = benchmark.interpolate()
    benchmark = benchmark.interpolate(limit_direction='backward')
    prices_df = prices_df.interpolate()
    prices_df = prices_df.interpolate(limit_direction='backward')
    
    for column in prices_df:
        
        rs = (prices_df[column][-window*4:] / benchmark[-window*4:]) * 100
        
        rs_ratio = rs.rolling(window).mean()
        
        rs_momentum = rs_ratio - rs_ratio.shift(5)
        
        #rel_momentum = 100 + ((rs_momentum - rs_momentum.mean()) / rs_momentum.std() + 1)
        rel_momentum = 100 + ((rs_momentum - rs_momentum.mean()) / rs_momentum.std())
        
        momentum_df[f'{column}_momentum'] = rel_momentum
        
    momentum_df.dropna(axis=0, how='all', inplace=True)
    
    return momentum_df

momentum_df = rs_momentum(data['Adj Close'], data[('Adj Close', 'SPY')])
print(momentum_df)
# Out:
#             GC=F_momentum  QLTA_momentum  SPY_momentum  ^TNX_momentum
# Date
# 2022-12-28     101.242898     101.960985           NaN     101.441770
# 2022-12-29     101.194577     101.600579           NaN     101.520232
# 2022-12-30     101.102688     101.128928           NaN     101.532747
# 2023-01-03     101.200275     101.092964           NaN     101.562478
# 2023-01-04     101.248456     101.263194           NaN     101.501615
# 2023-01-05     101.299301     101.456351           NaN     101.347856
# 2023-01-06     101.310126     101.364612           NaN     101.136197
# 2023-01-09     101.303097     101.253245           NaN     100.874868
# 2023-01-10     101.051169     100.790839           NaN     100.620805
# 2023-01-11     100.734001     100.379564           NaN     100.219479
# 2023-01-12     100.524015     100.099260           NaN      99.759913
# 2023-01-13     100.425945      99.931210           NaN      99.478894
# 2023-01-16     100.382609      99.898910           NaN      99.247162
# 2023-01-17     100.333010     100.030123           NaN      98.977756
# 2023-01-18     100.427060     100.265754           NaN      98.727736
# 2023-01-19     100.550274     100.530007           NaN      98.625325
# 2023-01-20     100.538202     100.790965           NaN      98.496771
# 2023-01-23     100.408289     100.729856           NaN      98.443407
# 2023-01-24     100.377109     100.683501           NaN      98.502419
# 2023-01-25     100.326466     100.399871           NaN      98.637148
# 2023-01-26     100.095682      99.917713           NaN      98.810146
# 2023-01-27      99.919048      99.565718           NaN      99.045998
# 2023-01-30      99.947206      99.640375           NaN      99.234134
# 2023-01-31      99.950068      99.636485           NaN      99.406796
# 2023-02-01      99.858249      99.641279           NaN      99.590870
# 2023-02-02      99.684983      99.603317           NaN      99.566995
# 2023-02-03      99.480057      99.647383           NaN      99.595058
# 2023-02-06      99.238167      99.499511           NaN      99.691351
# 2023-02-07      98.885497      98.979172           NaN      99.823870
# 2023-02-08      98.602659      98.596957           NaN      99.966950
# 2023-02-09      98.538958      98.518027           NaN     100.193410
# 2023-02-10      98.578421      98.507095           NaN     100.357901
# 2023-02-13      98.476283      98.356349           NaN     100.446480
# 2023-02-14      98.476961      98.581338           NaN     100.506032
# 2023-02-15      98.514224      98.797040           NaN     100.609686
# 2023-02-16      98.552519      98.883528           NaN     100.732854
# 2023-02-17      98.517364      98.853546           NaN     100.772235
# 2023-02-21      98.704089      99.124449           NaN     100.994659

# %% [raw]
# # chatgpt
#
# def calculate_RSR(ticker, benchmark='^GSPC', period='1mo'):
#     """
#     Calculate the relative strength ratio (RSR) of a stock compared to a benchmark index over a given time period.
#
#     Args:
#     - ticker (str): The ticker symbol of the stock to analyze.
#     - benchmark (str, optional): The ticker symbol of the benchmark index to compare against. Default is '^GSPC' (S&P 500).
#     - period (str, optional): The time period to analyze. Valid options are '1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', and 'max'. Default is '1mo' (1 month).
#
#     Returns:
#     - The RSR of the stock compared to the benchmark index over the given time period.
#     """
#     # Get historical prices for the stock and the benchmark index
#     stock_data = yf.download(ticker, period=period)['Adj Close']
#     benchmark_data = yf.download(benchmark, period=period)['Adj Close']
#
#     # Calculate the average daily returns for both the stock and the benchmark index
#     stock_returns = stock_data.pct_change().mean()
#     benchmark_returns = benchmark_data.pct_change().mean()
#
#     # Calculate the RSR
#     RSR = stock_returns / benchmark_returns
#
#     return RSR
#
# RSR = calculate_RSR('TSLA', benchmark='^DJI', period='1y')
# print(RSR)

# %%
def visualize_rs(symbol:str):
    fig, ax = plt.subplots(2, 1, figsize=(10, 8))
    ax[0].plot(ratio_df[f'{symbol}_ratio'], label=ratio_df.columns)
    ax[0].set_title('RS ratio')
    #ax[0].legend()

    ax[1].plot(momentum_df[f'{symbol}_momentum'], label=momentum_df.columns)
    ax[1].set_title('RS momentum')
    #ax[1].legend()
    plt.show()
    
visualize_rs('GC=F')

# %%
# merge rs ratio and momentum data
df = pd.merge(ratio_df, momentum_df, left_on=ratio_df.index, right_on=momentum_df.index).set_index('key_0')

print(df[-40:])
# Out:
#             GC=F_ratio  QLTA_ratio  SPY_ratio  ^TNX_ratio  GC=F_momentum  \
# key_0
# 2022-12-28   99.203444  100.729517        NaN  100.670624     101.242898
# 2022-12-29   99.367997  100.738878        NaN  100.887219     101.194577
# 2022-12-30   99.497269  100.734056        NaN  101.081363     101.102688
# 2023-01-03   99.769139  100.838800        NaN  101.244594     101.200275
# 2023-01-04   99.999800  100.938016        NaN  101.416865     101.248456
# 2023-01-05  100.226723  101.046162        NaN  101.604051     101.299301
# 2023-01-06  100.400013  101.014385        NaN  101.660768     101.310126
# 2023-01-09  100.523612  100.959624        NaN  101.657517     101.303097
# 2023-01-10  100.592177  100.857016        NaN  101.628840     101.051169
# 2023-01-11  100.566887  100.771808        NaN  101.497968     100.734001
# 2023-01-12  100.624353  100.754260        NaN  101.338019     100.524015
# 2023-01-13  100.718500  100.647127        NaN  101.182467     100.425945
# 2023-01-16  100.807128  100.577881        NaN  101.004177     100.382609
# 2023-01-17  100.835667  100.534111        NaN  100.772004     100.333010
# 2023-01-18  100.886274  100.554565        NaN  100.452277     100.427060
# 2023-01-19  101.043173  100.655514        NaN  100.214972     100.550274
# 2023-01-20  101.127578  100.665399        NaN   99.962317     100.538202
# 2023-01-23  101.111367  100.568751        NaN   99.743717     100.408289
# 2023-01-24  101.114744  100.504195        NaN   99.556119     100.377109
# 2023-01-25  101.124483  100.397464        NaN   99.338161     100.326466
# 2023-01-26  101.095141  100.282203        NaN   99.231530     100.095682
# 2023-01-27  101.037004  100.134247        NaN   99.157027      99.919048
# 2023-01-30  101.043516  100.071076        NaN   99.080536      99.947206
# 2023-01-31  101.049203  100.004776        NaN   99.023360      99.950068
# 2023-02-01  100.984845   99.900194        NaN   98.944441      99.858249
# 2023-02-02  100.815679   99.767910        NaN   98.819777      99.684983
# 2023-02-03  100.592168   99.639715        NaN   98.766471      99.480057
# 2023-02-06  100.403477   99.510236        NaN   98.762716      99.238167
# 2023-02-07  100.124561   99.210605        NaN   98.805638      98.885497
# 2023-02-08   99.831955   98.934631        NaN   98.834796      98.602659
# 2023-02-09   99.611383   98.766953        NaN   98.881189      98.538958
# 2023-02-10   99.419718   98.633855        NaN   98.952132      98.578421
# 2023-02-13   99.148603   98.436779        NaN   99.015285      98.476283
# 2023-02-14   98.870235   98.238038        NaN   99.103190      98.476961
# 2023-02-15   98.607699   98.058789        NaN   99.210643      98.514224
# 2023-02-16   98.418031   97.929893        NaN   99.350071      98.552519
# 2023-02-17   98.197997   97.783351        NaN   99.450761      98.517364
# 2023-02-21   98.077567   97.707753        NaN   99.681923      98.704089
#
#             QLTA_momentum  SPY_momentum  ^TNX_momentum
# key_0
# 2022-12-28     101.960985           NaN     101.441770
# 2022-12-29     101.600579           NaN     101.520232
# 2022-12-30     101.128928           NaN     101.532747
# 2023-01-03     101.092964           NaN     101.562478
# 2023-01-04     101.263194           NaN     101.501615
# 2023-01-05     101.456351           NaN     101.347856
# 2023-01-06     101.364612           NaN     101.136197
# 2023-01-09     101.253245           NaN     100.874868
# 2023-01-10     100.790839           NaN     100.620805
# 2023-01-11     100.379564           NaN     100.219479
# 2023-01-12     100.099260           NaN      99.759913
# 2023-01-13      99.931210           NaN      99.478894
# 2023-01-16      99.898910           NaN      99.247162
# 2023-01-17     100.030123           NaN      98.977756
# 2023-01-18     100.265754           NaN      98.727736
# 2023-01-19     100.530007           NaN      98.625325
# 2023-01-20     100.790965           NaN      98.496771
# 2023-01-23     100.729856           NaN      98.443407
# 2023-01-24     100.683501           NaN      98.502419
# 2023-01-25     100.399871           NaN      98.637148
# 2023-01-26      99.917713           NaN      98.810146
# 2023-01-27      99.565718           NaN      99.045998
# 2023-01-30      99.640375           NaN      99.234134
# 2023-01-31      99.636485           NaN      99.406796
# 2023-02-01      99.641279           NaN      99.590870
# 2023-02-02      99.603317           NaN      99.566995
# 2023-02-03      99.647383           NaN      99.595058
# 2023-02-06      99.499511           NaN      99.691351
# 2023-02-07      98.979172           NaN      99.823870
# 2023-02-08      98.596957           NaN      99.966950
# 2023-02-09      98.518027           NaN     100.193410
# 2023-02-10      98.507095           NaN     100.357901
# 2023-02-13      98.356349           NaN     100.446480
# 2023-02-14      98.581338           NaN     100.506032
# 2023-02-15      98.797040           NaN     100.609686
# 2023-02-16      98.883528           NaN     100.732854
# 2023-02-17      98.853546           NaN     100.772235
# 2023-02-21      99.124449           NaN     100.994659

# %%
def rrg_plot(df, symbol, period = 20):
    """
    Method to visualize RRG plot for one market/symbol. The benchmark is SPY
    """
    df = df.copy()
    df =df.iloc[-period:]
    
    last = df.iloc[-1]    
    others = df.iloc[:-1]    

    plt.axvline(x = 100, color = 'b')
    plt.axhline(y = 100, color = 'b')

    plt.plot(df[f'{symbol}_ratio'], df[f'{symbol}_momentum'])
    plt.scatter(last[f'{symbol}_ratio'], last[f'{symbol}_momentum'], marker='o')
    plt.scatter(others[f'{symbol}_ratio'], others[f'{symbol}_momentum'], marker='x')

    plt.title(symbol)
    plt.xlabel("RS ratio")
    plt.ylabel("RS momentum")

    plt.show()
    

rrg_plot(df, 'QLTA', 40)
rrg_plot(df, 'GC=F', 40)
rrg_plot(df, '^TNX', 40)
